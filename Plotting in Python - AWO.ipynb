# %% [markdown]
# ### Using Jupyter notebooks
# - List
# - Inline $\TeX$
# $$\sum_{i=1}{N}i^{2}=\frac{N(N+1)(2N+1)}{6}$$
# - Code block
# ```python
# print "Hello World"
# ```
# - Tables
#
# Column 1 | Column 2
# ---------|---------
# Row 1 | Entry 1
# Row 2 | Entry 2

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

from palettable.colorbrewer.sequential import Oranges_9

# %%
def factorial(x):
    if x <+ 1:
        return 1
    else:
        return x * factorial(x-1)

# %%
factorial(5)
# Out:
# 120

# %%
num_points = 50
xdata = np.zeros((num_points,1))
ydata = np.zeros((num_points,1))

# For loop
for i in range(1, num_points):
    xdata[i] = i
    ydata[i] = factorial(i)

# %%
fig = plt.figure(figsize=(4,3), dpi=200)

myriadpro = fm.FontProperties(fname='/usr/share/fonts/truetype/MyriadPro-Regular.ttf')

plt.semilogy(xdata, ydata, color=Oranges_9.mpl_colors[3], zorder=1)
#semilogy or plot
plt.scatter(xdata, ydata, color=Oranges_9.mpl_colors[5], s=4, zorder=2)

plt.title('Title', fontproperties=myriadpro, fontsize=16)
plt.xlabel('X Axis Label', fontproperties=myriadpro, fontsize=16)
plt.ylabel('Y Axis Label', fontproperties=myriadpro, fontsize=16)

plt.tick_params(direction='out', length=5, width=1.5)
plt.tight_layout()
plt.savefig('PlotAWO.png')
